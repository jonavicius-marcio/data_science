# %% [markdown]
# # Predicting House Prices

# %% [markdown]
# This dataset contains house sale prices for King County
#
# Target: make the exploratory analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
pd.set_option("display.max_columns", 200)
pd.set_option("display.max_rows", 50)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# # Read dataset

# %%
df_house = pd.read_csv('../src/data/house_prices.csv', parse_dates = ['date'],
                        dtype = {'id': np.str_,
                                'price': np.float32,
                                'bedrooms': np.float32,
                                'bathrooms': np.float32,
                                'sqft_living': np.float32,
                                'sqft_lot': np.int32, 
                                'floors': np.float32,
                                'waterfront': np.float32,
                                'view': np.float32,
                                'condition': np.float32,
                                'grade': np.float32,
                                'sqft_above': np.float32,
                                'sqft_basement': np.float32,
                                'yr_built': np.float32,
                                'yr_renovated': np.float32,
                                'zipcode': np.float32,
                                'lat': np.float32,
                                'long': np.float32,
                                'sqft': np.float32,
                                'living15': np.float32,
                                'sqft_lot15': np.float32,       
                    } 
)

# %%
df_house.head(2)
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13 221900.00      3.00       1.00      1180.00
# 1  6414100192 2014-12-09 538000.00      3.00       2.25      2570.00
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650    1.00        0.00  0.00       3.00   7.00     1180.00
# 1      7242    2.00        0.00  0.00       3.00   7.00     2170.00
#
#    sqft_basement  yr_built  yr_renovated  zipcode   lat    long  \
# 0           0.00   1955.00          0.00 98178.00 47.51 -122.26
# 1         400.00   1951.00       1991.00 98125.00 47.72 -122.32
#
#    sqft_living15  sqft_lot15
# 0           1340     5650.00
# 1           1690     7639.00

# %%
df_house.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df_house.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df_house.describe().transpose()
# Out:
#                  count      mean       std      min       25%       50%  \
# price         21613.00 540085.81 367126.97 75000.00 321950.00 450000.00
# bedrooms      21613.00      3.37      0.93     0.00      3.00      3.00
# bathrooms     21613.00      2.11      0.77     0.00      1.75      2.25
# sqft_living   21613.00   2079.91    918.44   290.00   1427.00   1910.00
# sqft_lot      21613.00  15106.97  41420.51   520.00   5040.00   7618.00
# floors        21613.00      1.49      0.54     1.00      1.00      1.50
# waterfront    21613.00      0.01      0.09     0.00      0.00      0.00
# view          21613.00      0.23      0.77     0.00      0.00      0.00
# condition     21613.00      3.41      0.65     1.00      3.00      3.00
# grade         21613.00      7.66      1.18     1.00      7.00      7.00
# sqft_above    21613.00   1788.40    828.09   290.00   1190.00   1560.00
# sqft_basement 21613.00    291.51    442.59     0.00      0.00      0.00
# yr_built      21613.00   1971.02     29.37  1900.00   1951.00   1975.00
# yr_renovated  21613.00     84.40    401.71     0.00      0.00      0.00
# zipcode       21613.00  98082.91     53.74 98001.00  98033.00  98065.00
# lat           21613.00     47.56      0.14    47.16     47.47     47.57
# long          21613.00   -122.21      0.14  -122.52   -122.33   -122.23
# sqft_living15 21613.00   1986.55    685.39   399.00   1490.00   1840.00
# sqft_lot15    21613.00  12768.44  27304.31   651.00   5100.00   7620.00
#
#                     75%        max
# price         645000.00 7700000.00
# bedrooms           4.00      33.00
# bathrooms          2.50       8.00
# sqft_living     2550.00   13540.00
# sqft_lot       10688.00 1651359.00
# floors             2.00       3.50
# waterfront         0.00       1.00
# view               0.00       4.00
# condition          4.00       5.00
# grade              8.00      13.00
# sqft_above      2210.00    9410.00
# sqft_basement    560.00    4820.00
# yr_built        1997.00    2015.00
# yr_renovated       0.00    2015.00
# zipcode        98118.00   98199.00
# lat               47.68      47.78
# long            -122.12    -121.32
# sqft_living15   2360.00    6210.00
# sqft_lot15     10083.00  871200.00

# %% [markdown]
# # Inspect each Column

# %%
for val in df_house:
    print(val)
    print(df_house[val].value_counts())
    print()
# Out:
# id
# 0795000620    3
# 8651510380    2
# 2568300045    2
# 9353300600    2
# 4139480200    2
#              ..
# 2767603649    1
# 1446403617    1
# 5602000275    1
# 1786200010    1
# 1523300157    1
# Name: id, Length: 21436, dtype: int64
#
# date
# 2014-06-23    142
# 2014-06-26    131
# 2014-06-25    131
# 2014-07-08    127
# 2015-04-27    126
#              ...
# 2014-11-02      1
# 2015-01-31      1
# 2015-05-24      1
# 2014-05-17      1
# 2014-07-27      1
# Name: date, Length: 372, dtype: int64
#
# price
# 350000.00     172
# 450000.00     172
# 550000.00     159
# 500000.00     152
# 425000.00     150
#              ...
# 607010.00       1
# 1362500.00      1
# 298800.00       1
# 957500.00       1
# 402101.00       1
# Name: price, Length: 4028, dtype: int64
#
# bedrooms
# 3.00     9824
# 4.00     6882
# 2.00     2760
# 5.00     1601
# 6.00      272
# 1.00      199
# 7.00       38
# 0.00       13
# 8.00       13
# 9.00        6
# 10.00       3
# 11.00       1
# 33.00       1
# Name: bedrooms, dtype: int64
#
# bathrooms
# 2.50    5380
# 1.00    3852
# 1.75    3048
# 2.25    2047
# 2.00    1930
# 1.50    1446
# 2.75    1185
# 3.00     753
# 3.50     731
# 3.25     589
# 3.75     155
# 4.00     136
# 4.50     100
# 4.25      79
# 0.75      72
# 4.75      23
# 5.00      21
# 5.25      13
# 0.00      10
# 5.50      10
# 1.25       9
# 6.00       6
# 0.50       4
# 5.75       4
# 6.75       2
# 8.00       2
# 6.25       2
# 6.50       2
# 7.50       1
# 7.75       1
# Name: bathrooms, dtype: int64
#
# sqft_living
# 1300.00    138
# 1400.00    135
# 1440.00    133
# 1800.00    129
# 1660.00    129
#           ...
# 9890.00      1
# 5584.00      1
# 1961.00      1
# 5720.00      1
# 1425.00      1
# Name: sqft_living, Length: 1038, dtype: int64
#
# sqft_lot
# 5000     358
# 6000     290
# 4000     251
# 7200     220
# 4800     120
#         ...
# 25248      1
# 9934       1
# 9142       1
# 24330      1
# 1076       1
# Name: sqft_lot, Length: 9782, dtype: int64
#
# floors
# 1.00    10680
# 2.00     8241
# 1.50     1910
# 3.00      613
# 2.50      161
# 3.50        8
# Name: floors, dtype: int64
#
# waterfront
# 0.00    21450
# 1.00      163
# Name: waterfront, dtype: int64
#
# view
# 0.00    19489
# 2.00      963
# 3.00      510
# 1.00      332
# 4.00      319
# Name: view, dtype: int64
#
# condition
# 3.00    14031
# 4.00     5679
# 5.00     1701
# 2.00      172
# 1.00       30
# Name: condition, dtype: int64
#
# grade
# 7.00     8981
# 8.00     6068
# 9.00     2615
# 6.00     2038
# 10.00    1134
# 11.00     399
# 5.00      242
# 12.00      90
# 4.00       29
# 13.00      13
# 3.00        3
# 1.00        1
# Name: grade, dtype: int64
#
# sqft_above
# 1300.00    212
# 1010.00    210
# 1200.00    206
# 1220.00    192
# 1140.00    184
#           ...
# 3674.00      1
# 2979.00      1
# 2382.00      1
# 6290.00      1
# 1425.00      1
# Name: sqft_above, Length: 946, dtype: int64
#
# sqft_basement
# 0.00      13126
# 600.00      221
# 700.00      218
# 500.00      214
# 800.00      206
#           ...
# 518.00        1
# 374.00        1
# 784.00        1
# 906.00        1
# 248.00        1
# Name: sqft_basement, Length: 306, dtype: int64
#
# yr_built
# 2014.00    559
# 2006.00    454
# 2005.00    450
# 2004.00    433
# 2003.00    422
#           ...
# 1933.00     30
# 1901.00     29
# 1902.00     27
# 1935.00     24
# 1934.00     21
# Name: yr_built, Length: 116, dtype: int64
#
# yr_renovated
# 0.00       20699
# 2014.00       91
# 2013.00       37
# 2003.00       36
# 2005.00       35
#            ...
# 1951.00        1
# 1959.00        1
# 1948.00        1
# 1954.00        1
# 1944.00        1
# Name: yr_renovated, Length: 70, dtype: int64
#
# zipcode
# 98103.00    602
# 98038.00    590
# 98115.00    583
# 98052.00    574
# 98117.00    553
#            ...
# 98102.00    105
# 98010.00    100
# 98024.00     81
# 98148.00     57
# 98039.00     50
# Name: zipcode, Length: 70, dtype: int64
#
# lat
# 47.66    17
# 47.53    17
# 47.68    17
# 47.55    17
# 47.70    16
#          ..
# 47.61     1
# 47.42     1
# 47.44     1
# 47.75     1
# 47.65     1
# Name: lat, Length: 5034, dtype: int64
#
# long
# -122.29    116
# -122.30    111
# -122.36    104
# -122.29    100
# -122.36     99
#           ...
# -121.69      1
# -122.51      1
# -121.65      1
# -122.51      1
# -121.40      1
# Name: long, Length: 752, dtype: int64
#
# sqft_living15
# 1540    197
# 1440    195
# 1560    192
# 1500    181
# 1460    169
#        ...
# 2054      1
# 3736      1
# 4950      1
# 2728      1
# 2927      1
# Name: sqft_living15, Length: 777, dtype: int64
#
# sqft_lot15
# 5000.00     427
# 4000.00     357
# 6000.00     289
# 7200.00     211
# 4800.00     145
#            ...
# 25927.00      1
# 35943.00      1
# 5107.00       1
# 1514.00       1
# 2007.00       1
# Name: sqft_lot15, Length: 8689, dtype: int64

# %%
df_house.groupby(["bedrooms"], dropna=False)["price"].count().reset_index()
# Out:
#     bedrooms  price
# 0       0.00     13
# 1       1.00    199
# 2       2.00   2760
# 3       3.00   9824
# 4       4.00   6882
# 5       5.00   1601
# 6       6.00    272
# 7       7.00     38
# 8       8.00     13
# 9       9.00      6
# 10     10.00      3
# 11     11.00      1
# 12     33.00      1

# %% [markdown]
# House Price Distribution

# %%
plt.figure(figsize = (8,4))
sns.histplot(df_house['price'],  kde=True)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %% [markdown]
# Correlation

# %%
corr = df_house.corr()
corr.shape
# Out:
# (19, 19)

# %%
# Plotting the heatmap of correlation between features
plt.figure(figsize=(10,10))

# mask
mask = np.triu(np.ones_like(corr, dtype=np.bool_))

# color map
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)


# title
title = 'Correlation Matrix'
plt.title(title, loc='left', fontsize=18)

sns.heatmap(corr, mask=mask, cbar=True, square= True, fmt='.1f', annot=True, annot_kws={'size':10}, cmap=cmap, linewidths=2 )
# Out:
# <AxesSubplot:title={'left':'Correlation Matrix'}>

# %% [markdown]
# The Highest correlated variables are: sqft_living, bathrooms, grade, sqft_above, and sqft_living15

# %% [markdown]
# Living Space Distribution

# %%
plt.figure(figsize = (8,4))
sns.histplot(df_house['sqft_living'],  kde=True)
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='Count'>

# %%
plt.figure(figsize = (10,4))
sns.scatterplot(x='sqft_living',y='price',data=df_house)
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %% [markdown]
# chart of no correlated var

# %%
plt.figure(figsize = (10,4))
sns.scatterplot(x='sqft_lot',y='price',data=df_house)
# Out:
# <AxesSubplot:xlabel='sqft_lot', ylabel='price'>

# %% [markdown]
# bedrooms

# %%
plt.figure(figsize = (8,4))
sns.countplot(df_house['bedrooms'])
# Out:
# c:\Users\marci\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
plt.figure(figsize = (8,4))
sns.boxplot(x='bedrooms',y='price',data=df_house)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %% [markdown]
# bathrooms

# %%
plt.figure(figsize = (8,4))
sns.histplot(df_house['bathrooms'],  kde=True)
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='Count'>

# %% [markdown]
# Grade

# %%
import pylab as P
plt.figure(figsize = (8,4))

df_house['grade'].hist()
P.show()

# %%
fig = sns.boxplot(x='grade', y='price', data=df_house)
fig.axis(ymin=0, ymax=5000000)
# Out:
# (-0.5, 11.5, 0.0, 5000000.0)
